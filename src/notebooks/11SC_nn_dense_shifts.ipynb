# %%
#Imports
from utils_sc_neuralnetworks import *

# %%
#1. SC Dense - Shift 0 - noPreselectDonors
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 0, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_0_noPreselectDonors/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': False,
    'donor_lookback': 0, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#       1 config = {
#       2     'data_path': '../../data/Energy_dataset_bessScaled.csv',
#       3     'buildings_range': range(1),
#    (...)
#      21     'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
#      22 }
#      24 sc = SyntheticControlNN()
# ---> 25 sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
#      26 sc_aggregated_stats
#
# File c:\Users\rs1044\Documents\GitHub\Advancing-Flexibility-in-Energy-Grids\src\notebooks\utils_sc_neuralnetworks.py:372, in SyntheticControlNN.run_sc_nn_multiple_buildings(cls, config)
#     369 sc.pre_split = config['pre_split']
#     371 # Run pipeline
# --> 372 sc.prepare_data(
#     373     config['data_path'], treated_unit_idx=building_idx,
#     374     shift_range=config["shift"], preselect_donors=config["preselect_donors"],
#     375     lookback=config["donor_lookback"])
#     377 if config["model_type"] == 'dense':
#     378     sc.sc_nn_dense_pipeline(
#     379         epochs=config["epochs"], batch_size=config["batch_size"],
#     380         validation_split=config["validation_split"],
#     381         dropout=config["dropout_rate"], learn_r=config["learning_rate"]
#     382         )
#
# File c:\Users\rs1044\Documents\GitHub\Advancing-Flexibility-in-Energy-Grids\src\notebooks\utils_sc_neuralnetworks.py:94, in SyntheticControlNN.prepare_data(self, path, treated_unit_idx, shift_range, preselect_donors, lookback)
#      91 Y0_pre_orig = self.Y0_pre  # shape: (T0, #donors)
#      92 self.Y0_pre = Y0_pre_orig.T  # shape: (#donors, T0)
# ---> 94 self.calculate_optimal_weights()  # populates self.weights
#      96 # Restore shape
#      97 self.Y0_pre = Y0_pre_orig  # (T0, #donors)
#
# File c:\Users\rs1044\Documents\GitHub\Advancing-Flexibility-in-Energy-Grids\src\notebooks\utils_sc_neuralnetworks.py:148, in SyntheticControlNN.calculate_optimal_weights(self)
#     146 obj = gp.quicksum(e_plus[t] + e_minus[t] for t in range(T0))
#     147 model.setObjective(obj, GRB.MINIMIZE)
# --> 148 model.optimize()
#     150 if model.status == GRB.OPTIMAL:
#     151     self.weights = np.array([W[j].X for j in range(J)])
#
# KeyboardInterrupt:

# %%
#2. SC Dense - Shift 0 - Preselect Donors
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 0, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_0_PreselectDonors/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': True,
    'donor_lookback': 0, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats

# %%
#3. SC Dense - Shift 1 - NO preselect donors
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 1, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_1_noPreselectDonors/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': False,
    'donor_lookback': 0, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats

# %%
#4. SC Dense - Shift 1 - preselect donors
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 1, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_1_PreselectDonors/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': True,
    'donor_lookback': 0, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats

# %%
#5. SC Dense - Shift 0 - preselect donors - LOOKBACK 1
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 0, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_0_PreselectDonors_Lookback1/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': True,
    'donor_lookback': 1, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats

# %%
#6. SC Dense - Shift 0 - preselect donors - LOOKBACK 3
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 0, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_0_PreselectDonors_Lookback3/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': True,
    'donor_lookback': 3, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats

# %%
#7. SC Dense - Shift 0 - preselect donors - LOOKBACK 5
config = {
    'data_path': '../../data/Energy_dataset_bessScaled.csv',
    'buildings_range': range(50),
    'pre_split': 0.7,
    'shift': 0, # [0,1,2] Best 0
    
    'save_path': "results/sc/sc_dense/shift_0_PreselectDonors_Lookback5/",
    'visualize': False,
    'plot_training_history': False,
    'periods_to_plot': 3*48,

    'preselect_donors': True,
    'donor_lookback': 5, # 0 (no lookback), 1, 2, 3, ...
    
    'model_type': 'dense', #['dense', 'lstm']
    'learning_rate': 0.0005, # [0.001 to 0.0001] Best 0.0005
    'batch_size': 32, #[32 to 128] Best 32
    'iterations': 3,
    'epochs': 100, #100
    'validation_split': 0.2,
    'dropout_rate':0.1, #[0.1 to 0.3] Best 0.1
}

sc = SyntheticControlNN()
sc_values, sc_metrics, sc_aggregated_stats = sc.run_sc_nn_multiple_buildings(config)
sc_aggregated_stats
